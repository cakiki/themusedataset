# %% [markdown]
# # A Tour of the MuSe Dataset
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
import pandas as pd
# Out:
# <style>.container { width:80% !important; }</style>

# %%
# %%time
muse = pd.read_pickle('muse_final.pkl')
# Out:
# CPU times: user 14.3 s, sys: 737 ms, total: 15 s
# Wall time: 15 s

# %%
muse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96499 entries, 0 to 96498
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pylast                    96499 non-null  object
#  1   track                     96499 non-null  object
#  2   artist                    96499 non-null  object
#  3   lastfm_url                96499 non-null  object
#  4   all_music_mood            96499 non-null  object
#  5   tag_objects               96499 non-null  object
#  6   weighted_tags             96499 non-null  object
#  7   weighted_mood             96499 non-null  object
#  8   weighted_genre            88590 non-null  object
#  9   genre                     88590 non-null  object
#  10  valence_tags              90408 non-null  float64
#  11  arousal_tags              90408 non-null  float64
#  12  dominance_tags            90408 non-null  float64
#  13  mbid                      65076 non-null  object
#  14  spotify_id                65508 non-null  object
#  15  spotify_song_popularity   65508 non-null  float64
#  16  spotify_song_is_explicit  65508 non-null  object
#  17  spotify_danceability      65498 non-null  float64
#  18  spotify_energy            65498 non-null  float64
#  19  spotify_key               65498 non-null  float64
#  20  spotify_loudness          65498 non-null  float64
#  21  spotify_mode              65498 non-null  float64
#  22  spotify_speechiness       65498 non-null  float64
#  23  spotify_acousticness      65498 non-null  float64
#  24  spotify_instrumentalness  65498 non-null  float64
#  25  spotify_liveness          65498 non-null  float64
#  26  spotify_valence           65498 non-null  float64
#  27  spotify_tempo             65498 non-null  float64
#  28  spotify_duration_ms       65498 non-null  float64
#  29  spotify_time_signature    65498 non-null  float64
# dtypes: float64(17), object(13)
# memory usage: 22.8+ MB

# %%
muse.describe()
# Out:
#        valence_tags  arousal_tags  dominance_tags  spotify_song_popularity  \
# count  90408.000000  90408.000000    90408.000000             65508.000000
# mean       5.453879      4.317195        5.245569                21.374031
# std        1.552993      1.154660        1.171162                17.110926
# min        0.235000      0.108113        0.229231                 0.000000
# 25%        4.280000      3.528000        4.550862                 7.000000
# 50%        5.650000      4.330000        5.460000                19.000000
# 75%        6.695476      5.150000        6.115000                32.000000
# max        8.475000      7.270000        7.440000                96.000000
#
#        spotify_danceability  spotify_energy   spotify_key  spotify_loudness  \
# count          65498.000000    65498.000000  65498.000000      65498.000000
# mean               0.496619        0.577624      5.230435        -10.043309
# std                0.179263        0.268366      3.562924          5.305236
# min                0.000000        0.000020      0.000000        -47.432000
# 25%                0.371000        0.369000      2.000000        -12.589750
# 50%                0.507000        0.600000      5.000000         -8.915000
# 75%                0.627000        0.810000      8.000000         -6.246000
# max                0.990000        1.000000     11.000000          5.118000
#
#        spotify_mode  spotify_speechiness  spotify_acousticness  \
# count  65498.000000         65498.000000          65498.000000
# mean       0.652234             0.070759              0.336803
# std        0.476265             0.089021              0.351047
# min        0.000000             0.000000              0.000000
# 25%        0.000000             0.033200              0.014400
# 50%        1.000000             0.041900              0.183000
# 75%        1.000000             0.065300              0.670000
# max        1.000000             0.966000              0.996000
#
#        spotify_instrumentalness  spotify_liveness  spotify_valence  \
# count              65498.000000      65498.000000     65498.000000
# mean                   0.256107          0.197867         0.407426
# std                    0.356163          0.171557         0.260556
# min                    0.000000          0.000000         0.000000
# 25%                    0.000019          0.097500         0.184000
# 50%                    0.009390          0.124000         0.375000
# 75%                    0.593000          0.244000         0.608000
# max                    1.000000          1.000000         0.998000
#
#        spotify_tempo  spotify_duration_ms  spotify_time_signature
# count   65498.000000         6.549800e+04            65498.000000
# mean      120.249669         2.666169e+05                3.874882
# std        29.808614         1.436984e+05                0.466141
# min         0.000000         2.533000e+03                0.000000
# 25%        97.432000         1.959200e+05                4.000000
# 50%       119.958000         2.413330e+05                4.000000
# 75%       139.191000         3.007330e+05                4.000000
# max       222.605000         4.440760e+06                5.000000
